# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

import os
import pickle
import random
import numpy as np
import pandas as pd
import networkx as nx
from tqdm import tqdm
import community as community_louvain

import matplotlib.cm as cmx
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.patches as mpatches

pd.options.mode.chained_assignment = None

# %% [markdown]
# # Importing & Preparing Data

# %%
PATH = 'data/co-authorship-network/'

# %%
edges = pd.read_table(PATH + '/edges.txt', sep=',', header=None)
edges.columns = ["source", "target"]
edges_original = edges.copy()

nodes = pd.read_table(PATH + '/nodes.txt', header=None)
nodes.columns=["Node ID"]

data = pd.read_table(PATH + '/gs_info.txt', sep=' ', header=None)
data.columns=["Node ID", "Number of Citations", "H-Index", "G-Index", "Academic Title", "Computer Science", "Biology", "Sociology"]
data.head(3)
# Out:
#    Node ID  Number of Citations  H-Index  G-Index  Academic Title  \
# 0        0                   80        3        8               0
# 1        1                  369        9       19               3
# 2        2                  597        9       24               0
#
#    Computer Science  Biology  Sociology
# 0                 0        0          0
# 1                 0        0          0
# 2                 0        0          0

# %%
data.shape, edges.shape
# Out:
# ((402392, 8), (1234019, 2))

# %% [markdown]
# # Data Preparation

# %%
def get_discipline(row):
    cs, bio, soc = row
    if sum(row) == 1:
        if cs:
            return "Computer Science"
        if bio:
            return "Biology"
        if soc:
            return "Sociology"
    elif sum(row) == 2:
        if cs and bio:
            return "Computer Science and Biology"
        if bio and soc:
            return "Biology and Sociology"
        if cs and soc:
            return "Computer Science and Sociology"
    elif sum(row) == 3:
        return "Computer Science, Biology, and Sociology"
    else:
        return "N/A"

# %%
# Remove nodes from df 'data' that don't have a category
field_data = data[['Node ID', 'Computer Science', 'Biology', 'Sociology']]
field_data['Discipline'] = field_data.iloc[:, 1:].apply(get_discipline, axis=1)
cat_df = pd.DataFrame({"Node ID" : field_data['Node ID'],
                       "Discipline" : field_data['Discipline']})
cat_df['Discipline'] = pd.Categorical(cat_df['Discipline'])

# Remove N/A discipline Nodes from the edges df
cat_df = cat_df[~cat_df['Discipline'].isin(["N/A"])].reset_index(drop=True).set_index('Node ID')

# Remove Sociology Affiliates
sociology_nodes = cat_df[cat_df.Discipline.isin(['Sociology', 'Computer Science and Sociology', 'Biology and Sociology', 
                                    'Computer Science, Biology, and Sociology'])].index
cat_df = cat_df[~cat_df.Discipline.isin(['Sociology', 'Computer Science and Sociology', 'Biology and Sociology', 
                                    'Computer Science, Biology, and Sociology'])]
cat_df.Discipline = cat_df.Discipline.cat.remove_unused_categories()

# %%
# Construct graph from edgelist & truncate the graph and cat_df
G = nx.from_pandas_edgelist(edges)
G = G.subgraph(cat_df.index)
cat_df = cat_df[cat_df.index.isin(G.nodes)]

# %%
for node_id, discipline in cat_df['Discipline'].iteritems():
    G.nodes[node_id]['Discipline'] = discipline

# %%
cat_df = pd.read_csv("Categorical_DF_majority_discipline.csv").set_index('Node ID')

# %% [markdown]
# # Finding Largest Connected Component

# %%
# Define a BFS function that returns the connected component and stops when the size limit is reached
def bfs_connected_component(graph, start_node, size_limit):
    visited = set()
    queue = [start_node]

    while queue:
        node = queue.pop(0)
        if node not in visited:
            visited.add(node)
            if len(visited) >= size_limit:
                break
            neighbors = list(graph.neighbors(node))
            queue.extend(neighbors)

    return visited

def get_random_cc_with_categories(size_limit, min_percentage=0.3):
    connected_component = set()
    while True:
        # Pick a random node and perform BFS until you find a connected component w/size limit
        random_node = random.choice(list(G.nodes()))
        connected_component = bfs_connected_component(G, random_node, size_limit)

        # Create a subgraph of the connected component
        G_cc = G.subgraph(connected_component)

        # Count the number of nodes for each category in the connected component
        cat_counts = cat_df[cat_df.index.isin(G_cc.nodes())]['Discipline'].value_counts()
        cat_percentages = cat_counts / len(connected_component)

        # Check if at least two categories have more than min_percentage nodes
        if (cat_percentages >= min_percentage).sum() >= 2:
            # print(str(cat_percentages) + "\n---------------------")
            return connected_component

# %%
def draw_graph(G, cat_df=cat_df):
    # Get the values of the category
    cat_values = cat_df[cat_df.index.isin(G.nodes)]['Discipline'].unique()
    colors = [plt.cm.Set2(i/float(len(cat_values)-1)) for i in range(len(cat_values))]

    # Create a dictionary mapping category values to colors & map nodes to colors
    value_to_color = dict(zip(cat_values, colors))
    node_colors = [value_to_color[cat_df.loc[n]['Discipline']] for n in G_cc.nodes()]

    # Draw the graph
    plt.figure(figsize=(5, 5))
    nx.draw(G, node_size=25, node_color=node_colors)

    # Create a patch for each category value
    patches = [plt.plot([],[], marker="o", color=colors[i], 
               label="{}".format(cat_values[i]))[0] for i in range(len(cat_values))]

    # Add legend
    plt.legend(handles=patches);
    
def draw_cat_distribution(G, cat_df=cat_df):
    cat_df_subset = cat_df[cat_df.index.isin(G.nodes)]
    cat_df_subset.Discipline = cat_df_subset.Discipline.cat.remove_unused_categories()
    cat_df_subset['Discipline'].value_counts().plot(kind='bar');

# %% [markdown]
# # Finding Subgraphs with Community Structure

# %%
def save_obj(obj, filename):
    with open(filename, 'wb') as f:
        pickle.dump(obj, f)

def load_obj(filename):
    with open(filename, 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# Louvain will exclude cross-community edges;
# alternate - pick a random node; do a BFS 'till certain thresholds (e.g. x nodes from category 1, y nodes from cat. 2).

# %% [markdown]
# # Plotting in-group degree vs. out-group degrees

# %%
def save_graph_image(G, clusters, cat_df, filename):
    fig, ax = plt.subplots(figsize=(20, 20))
    draw_graph(G)
    plt.savefig(filename, dpi=300)
    plt.close(fig)

graphs_found = 5
graphs_dir = "graphs"

if not os.path.exists(graphs_dir):
    os.makedirs(graphs_dir)

counter = 1
while graphs_found < 10:
    cc = get_random_cc_with_categories(2000)
    G_cc, cat_df_cc = G.subgraph(cc), cat_df[cat_df.index.isin(cc)]
    cat_df_cc['Discipline'] = cat_df_cc['Discipline'].astype('category')

    has_clusters, clusters, broker_nodes = has_large_clusters(G_cc, cat_df_cc, large_cluster_size_threshold=300, return_clusters=True)

    if has_clusters:
        print(f"Found a graph with clusters!")

        graph_filename = os.path.join(graphs_dir, f"graph_{graphs_found + 1}_object.pkl")
        save_obj(G_cc, graph_filename)
        print(f"Saved graph {graphs_found + 1} object as {graph_filename}")

        image_filename = os.path.join(graphs_dir, f"graph_{graphs_found + 1}_image.png")
        save_graph_image(G_cc, clusters, cat_df_cc, image_filename)
        print(f"Saved graph {graphs_found + 1} image as {image_filename}")

        graphs_found += 1
    else:
        print(f"Random graph {counter} does not have large clusters.")
    counter += 1
# Out:
# Random graph 1 does not have large clusters.
# Found a graph with clusters!
# Saved graph 2 object as graphs\graph_2_object.pkl
# Saved graph 2 image as graphs\graph_2_image.png
# Random graph 3 does not have large clusters.
# Random graph 4 does not have large clusters.
# Found a graph with clusters!
# Saved graph 3 object as graphs\graph_3_object.pkl
# Saved graph 3 image as graphs\graph_3_image.png
# Random graph 6 does not have large clusters.
# Random graph 7 does not have large clusters.
# Random graph 8 does not have large clusters.
# Random graph 9 does not have large clusters.
# Random graph 10 does not have large clusters.
# Random graph 11 does not have large clusters.
# Random graph 12 does not have large clusters.
# Random graph 13 does not have large clusters.
# Random graph 14 does not have large clusters.
# Random graph 15 does not have large clusters.
# Random graph 16 does not have large clusters.
# Random graph 17 does not have large clusters.
# Random graph 18 does not have large clusters.
# Random graph 19 does not have large clusters.
# Random graph 20 does not have large clusters.
# Random graph 21 does not have large clusters.
# Random graph 22 does not have large clusters.
# Random graph 23 does not have large clusters.
# Random graph 24 does not have large clusters.
# Random graph 25 does not have large clusters.
# Random graph 26 does not have large clusters.
# Random graph 27 does not have large clusters.
# Random graph 28 does not have large clusters.
# Random graph 29 does not have large clusters.
# Random graph 30 does not have large clusters.
# Random graph 31 does not have large clusters.
# Random graph 32 does not have large clusters.
# Random graph 33 does not have large clusters.
# Random graph 34 does not have large clusters.
# Random graph 35 does not have large clusters.
# Random graph 36 does not have large clusters.
# Random graph 37 does not have large clusters.
# Random graph 38 does not have large clusters.
# Random graph 39 does not have large clusters.
# Random graph 40 does not have large clusters.
# Found a graph with clusters!
# Saved graph 4 object as graphs\graph_4_object.pkl
# Saved graph 4 image as graphs\graph_4_image.png
# Random graph 42 does not have large clusters.
# Random graph 43 does not have large clusters.
# Random graph 44 does not have large clusters.
# Random graph 45 does not have large clusters.
# Random graph 46 does not have large clusters.
# Found a graph with clusters!
# Saved graph 5 object as graphs\graph_5_object.pkl
# Saved graph 5 image as graphs\graph_5_image.png
# Random graph 48 does not have large clusters.
# Random graph 49 does not have large clusters.
# Random graph 50 does not have large clusters.
# Random graph 51 does not have large clusters.
# Random graph 52 does not have large clusters.
# Random graph 53 does not have large clusters.
# Random graph 54 does not have large clusters.
# Random graph 55 does not have large clusters.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[137], line 19
#      16 G_cc, cat_df_cc = G.subgraph(cc), cat_df[cat_df.index.isin(cc)]
#      17 cat_df_cc['Discipline'] = cat_df_cc['Discipline'].astype('category')
# ---> 19 has_clusters, clusters, broker_nodes = has_large_clusters(G_cc, cat_df_cc, large_cluster_size_threshold=300, return_clusters=True)
#      21 if has_clusters:
#      22     print(f"Found a graph with clusters!")
#
# Cell In[90], line 25, in has_large_clusters(G, cat_df, large_cluster_size_threshold, broker_nodes_threshold, category_similarity_threshold, return_clusters)
#      23 for node2 in cluster2:
#      24     try:
# ---> 25         path_length = nx.shortest_path_length(G, node1, node2)
#      26         if path_length < shortest_path_length:
#      27             shortest_path_length = path_length
#
# File ~\miniconda3\envs\network_research\Lib\site-packages\networkx\classes\backends.py:145, in _dispatch.<locals>.wrapper(*args, **kwds)
#     141         else:
#     142             raise NetworkXNotImplemented(
#     143                 f"'{name}' not implemented by {plugin_name}"
#     144             )
# --> 145 return func(*args, **kwds)
#
# File ~\miniconda3\envs\network_research\Lib\site-packages\networkx\algorithms\shortest_paths\generic.py:310, in shortest_path_length(G, source, target, weight, method)
#     307 else:
#     308     # Find shortest source-target path.
#     309     if method == "unweighted":
# --> 310         p = nx.bidirectional_shortest_path(G, source, target)
#     311         paths = len(p) - 1
#     312     elif method == "dijkstra":
#
# File ~\miniconda3\envs\network_research\Lib\site-packages\networkx\algorithms\shortest_paths\unweighted.py:224, in bidirectional_shortest_path(G, source, target)
#     221     raise nx.NodeNotFound(msg)
#     223 # call helper to do the real work
# --> 224 results = _bidirectional_pred_succ(G, source, target)
#     225 pred, succ, w = results
#     227 # build path from pred+w+succ
#
# File ~\miniconda3\envs\network_research\Lib\site-packages\networkx\algorithms\shortest_paths\unweighted.py:285, in _bidirectional_pred_succ(G, source, target)
#     283 reverse_fringe = []
#     284 for v in this_level:
# --> 285     for w in Gpred[v]:
#     286         if w not in succ:
#     287             succ[w] = v
#
# File ~\miniconda3\envs\network_research\Lib\site-packages\networkx\classes\coreviews.py:281, in <genexpr>(.0)
#     279 if node_ok_shorter:
#     280     return (n for n in self.NODE_OK.nodes if n in self._atlas)
# --> 281 return (n for n in self._atlas if self.NODE_OK(n))
#
# File ~\miniconda3\envs\network_research\Lib\site-packages\networkx\classes\coreviews.py:317, in FilterAdjacency.__getitem__.<locals>.new_node_ok(nbr)
#     316 def new_node_ok(nbr):
# --> 317     return self.NODE_OK(nbr) and self.EDGE_OK(node, nbr)
#
# File ~\miniconda3\envs\network_research\Lib\site-packages\networkx\classes\filters.py:20, in no_filter(*items)
#       1 """Filter factories to hide or show sets of nodes and edges.
#       2
#       3 These filters return the function used when creating `SubGraph`.
#       4 """
#       5 __all__ = [
#       6     "no_filter",
#       7     "hide_nodes",
#    (...)
#      16     "show_multidiedges",
#      17 ]
# ---> 20 def no_filter(*items):
#      21     return True
#      24 def hide_nodes(nodes):
#
# KeyboardInterrupt:

# %%
def get_node_degrees(node, graph, group0, group1):
    connections0, connections1 = 0, 0
    for neighbor in graph.neighbors(node):
        if neighbor in group0:
            connections0 += 1
        elif neighbor in group1:
            connections1 += 1
    return connections0, connections1

def plot_group_degrees(G_cc, cat_df_cc, cat_values):
    # Separate nodes in the connected component into groups based on their Discipline value
    nodes_groups = {value: [n for n in G_cc.nodes() if cat_df_cc.loc[n]['Discipline'] == value] for value in cat_values}

    # Filter nodes_groups to exclude categories with no nodes
    nodes_groups_filtered = {value: nodes for value, nodes in nodes_groups.items() if len(nodes) > 0}
    filtered_cat_values = list(nodes_groups_filtered.keys())

    # Calculate in-group and out-group degrees for each group with nodes
    group_degrees = {}
    for value, nodes in nodes_groups_filtered.items():
        in_group_degrees, out_group_degrees = [], []
        for node in nodes:
            other_groups = [nodes_groups_filtered[other_value] for other_value in filtered_cat_values if other_value != value]
            other_nodes = [item for sublist in other_groups for item in sublist]
            connections_in_group, connections_out_group = get_node_degrees(node, G_cc, nodes, other_nodes)
            in_group_degrees.append(connections_in_group)
            out_group_degrees.append(connections_out_group)
        group_degrees[value] = (in_group_degrees, out_group_degrees)

    # Plot histograms of in-group and out-group degrees for groups with nodes
    fig, axs = plt.subplots(len(filtered_cat_values), 2, figsize=(10, 5 * len(filtered_cat_values)))
    max_bin_width = 1

    for i, value in enumerate(filtered_cat_values):
        # Calculate the range of in-group and out-group degrees
        in_group_range = np.ptp(group_degrees[value][0])
        out_group_range = np.ptp(group_degrees[value][1])

        # Calculate the number of bins, making sure the bin width doesn't go below max_bin_width
        in_group_bins = max(int(in_group_range / max_bin_width), 1)
        out_group_bins = max(int(out_group_range / max_bin_width), 1)

        # In-group degree histogram for the current group
        axs[i, 0].hist(group_degrees[value][0], bins=in_group_bins, density=True)
        axs[i, 0].set_xlabel('In-group degree')
        axs[i, 0].set_ylabel('Proportion of nodes')
        axs[i, 0].set_title(f'In-group Degree Histogram for {value}')
    
        # Out-group degree histogram for the current group
        axs[i, 1].hist(group_degrees[value][1], bins=out_group_bins, density=True)
        axs[i, 1].set_xlabel('Out-group degree')
        axs[i, 1].set_ylabel('Proportion of nodes')
        axs[i, 1].set_title(f'Out-group Degree Histogram for {value}')

    plt.subplots_adjust(top=0.9, hspace=0.4)

# %%
cat_df_cc = cat_df[cat_df.index.isin(G_cc.nodes())]
plot_group_degrees(G_cc, cat_df_cc, list(cat_df_cc.Discipline.unique()))
